# %%
import os
import cv2 as cv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow
from google.colab import drive
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
import keras.layers.experimental.preprocessing
from keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
BASE_PATH = './drive/MyDrive/Visione e Percezione/'
DATASET_PATH = BASE_PATH + 'dataset/imgs/'

INPUT_SIZE = 150
BATCH_SIZE = 32

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = image_dataset_from_directory(DATASET_PATH, 
                                        image_size = (INPUT_SIZE, INPUT_SIZE))
# Out:
# Found 1495 files belonging to 3 classes.

# %%
x = []
y = []
for image, label in tqdm(dataset.unbatch().take(-1)):
    img = image.numpy().astype("uint8")
    x.append(img)
    label = label.numpy()
    y.append(label)

x = np.array(x)
y = np.array(y)
# Out:
# 1495it [03:50,  6.48it/s]

# %%
x_train, x_val_test, y_train, y_val_test = train_test_split(x, y, test_size=0.4)
x_val, x_test, y_val, y_test = train_test_split(x_val_test, y_val_test, test_size=0.5)

# %%
model = Sequential()

model.add(Rescaling(1./255, input_shape=(INPUT_SIZE, INPUT_SIZE, 3)))
model.add(RandomFlip("horizontal"))
model.add(RandomRotation(0.1))
model.add(RandomZoom(0.1))        

model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3))

model.compile(loss=SparseCategoricalCrossentropy(from_logits=True), optimizer='adam',  metrics=['accuracy'])

# %%
history = model.fit(
    x_train, y_train,
    validation_data = (x_val, y_val),
    epochs=50,
    verbose=1
)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 55s 64ms/step - loss: 1.5552 - accuracy: 0.3533 - val_loss: 1.0960 - val_accuracy: 0.5418
# Epoch 2/50
# 29/29 [==============================] - 1s 33ms/step - loss: 1.0851 - accuracy: 0.3772 - val_loss: 1.0390 - val_accuracy: 0.3679
# Epoch 3/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.8558 - accuracy: 0.5779 - val_loss: 1.1818 - val_accuracy: 0.3579
# Epoch 4/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.6775 - accuracy: 0.6872 - val_loss: 0.8203 - val_accuracy: 0.5151
# Epoch 5/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4477 - accuracy: 0.8024 - val_loss: 0.8564 - val_accuracy: 0.5485
# Epoch 6/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.3076 - accuracy: 0.8739 - val_loss: 1.1852 - val_accuracy: 0.5552
# Epoch 7/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.2115 - accuracy: 0.9411 - val_loss: 1.2498 - val_accuracy: 0.5753
# Epoch 8/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1529 - accuracy: 0.9475 - val_loss: 1.1095 - val_accuracy: 0.6522
# Epoch 9/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1011 - accuracy: 0.9574 - val_loss: 0.8640 - val_accuracy: 0.6555
# Epoch 10/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1507 - accuracy: 0.9515 - val_loss: 0.9305 - val_accuracy: 0.6555
# Epoch 11/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0544 - accuracy: 0.9802 - val_loss: 1.0286 - val_accuracy: 0.6522
# Epoch 12/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0808 - accuracy: 0.9759 - val_loss: 1.1075 - val_accuracy: 0.6555
# Epoch 13/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0617 - accuracy: 0.9725 - val_loss: 0.5975 - val_accuracy: 0.6789
# Epoch 14/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0600 - accuracy: 0.9774 - val_loss: 0.6239 - val_accuracy: 0.6622
# Epoch 15/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0394 - accuracy: 0.9829 - val_loss: 0.7964 - val_accuracy: 0.6923
# Epoch 16/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1012 - accuracy: 0.9686 - val_loss: 1.1008 - val_accuracy: 0.6555
# Epoch 17/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0847 - accuracy: 0.9775 - val_loss: 1.2410 - val_accuracy: 0.6522
# Epoch 18/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0386 - accuracy: 0.9839 - val_loss: 1.2956 - val_accuracy: 0.6522
# Epoch 19/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0479 - accuracy: 0.9772 - val_loss: 0.3885 - val_accuracy: 0.7926
# Epoch 20/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0557 - accuracy: 0.9801 - val_loss: 0.8220 - val_accuracy: 0.6555
# Epoch 21/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0423 - accuracy: 0.9881 - val_loss: 0.9653 - val_accuracy: 0.6555
# Epoch 22/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0578 - accuracy: 0.9807 - val_loss: 0.1315 - val_accuracy: 0.9632
# Epoch 23/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0969 - accuracy: 0.9657 - val_loss: 0.5547 - val_accuracy: 0.6589
# Epoch 24/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0523 - accuracy: 0.9851 - val_loss: 0.5929 - val_accuracy: 0.6622
# Epoch 25/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.0327 - accuracy: 0.9858 - val_loss: 0.7980 - val_accuracy: 0.6622
# Epoch 26/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0374 - accuracy: 0.9744 - val_loss: 0.8154 - val_accuracy: 0.6622
# Epoch 27/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0438 - accuracy: 0.9785 - val_loss: 0.1103 - val_accuracy: 0.9599
# Epoch 28/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.1238 - accuracy: 0.9691 - val_loss: 0.8031 - val_accuracy: 0.6555
# Epoch 29/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0444 - accuracy: 0.9874 - val_loss: 0.3376 - val_accuracy: 0.7893
# Epoch 30/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0439 - accuracy: 0.9774 - val_loss: 0.9649 - val_accuracy: 0.6555
# Epoch 31/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0531 - accuracy: 0.9848 - val_loss: 0.1071 - val_accuracy: 0.9666
# Epoch 32/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0782 - accuracy: 0.9726 - val_loss: 0.7889 - val_accuracy: 0.6589
# Epoch 33/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0433 - accuracy: 0.9796 - val_loss: 1.5720 - val_accuracy: 0.6555
# Epoch 34/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0518 - accuracy: 0.9814 - val_loss: 0.0810 - val_accuracy: 0.9699
# Epoch 35/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0405 - accuracy: 0.9881 - val_loss: 0.1774 - val_accuracy: 0.9164
# Epoch 36/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0423 - accuracy: 0.9782 - val_loss: 0.6735 - val_accuracy: 0.6756
# Epoch 37/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0208 - accuracy: 0.9906 - val_loss: 0.8498 - val_accuracy: 0.6622
# Epoch 38/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0307 - accuracy: 0.9841 - val_loss: 0.6169 - val_accuracy: 0.7860
# Epoch 39/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0157 - accuracy: 0.9901 - val_loss: 0.3105 - val_accuracy: 0.8528
# Epoch 40/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0304 - accuracy: 0.9884 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 41/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.3135 - accuracy: 0.9208 - val_loss: 0.9427 - val_accuracy: 0.6890
# Epoch 42/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0685 - accuracy: 0.9698 - val_loss: 0.8427 - val_accuracy: 0.6589
# Epoch 43/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0765 - accuracy: 0.9602 - val_loss: 0.9193 - val_accuracy: 0.6488
# Epoch 44/50
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0473 - accuracy: 0.9824 - val_loss: 0.7483 - val_accuracy: 0.6656
# Epoch 45/50
# 29/29 [==============================] - 1s 37ms/step - loss: 0.0397 - accuracy: 0.9846 - val_loss: 1.3898 - val_accuracy: 0.6555
# Epoch 46/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0219 - accuracy: 0.9935 - val_loss: 1.0986 - val_accuracy: 0.6555
# Epoch 47/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0374 - accuracy: 0.9827 - val_loss: 1.5104 - val_accuracy: 0.6555
# Epoch 48/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0258 - accuracy: 0.9879 - val_loss: 0.8564 - val_accuracy: 0.7157
# Epoch 49/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0272 - accuracy: 0.9862 - val_loss: 0.6837 - val_accuracy: 0.7625
# Epoch 50/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0892 - accuracy: 0.9644 - val_loss: 0.1969 - val_accuracy: 0.9365

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_32 (ModuleWra (None, 150, 150, 3)       0
# _________________________________________________________________
# module_wrapper_33 (ModuleWra (None, 150, 150, 3)       0
# _________________________________________________________________
# module_wrapper_34 (ModuleWra (None, 150, 150, 3)       0
# _________________________________________________________________
# module_wrapper_35 (ModuleWra (None, 150, 150, 3)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 75, 75, 32)        0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 41472)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                2654272
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 2,747,715
# Trainable params: 2,747,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
 model.save(BASE_PATH + 'model/cnn_model.h5')

# %%
predictions = np.argmax(model.predict(x_test), axis=-1)
predictions = predictions.reshape(1,-1)[0]

conf_mat = confusion_matrix(y_test, predictions)
pd.DataFrame(conf_mat)
# Out:
#     0   1    2
# 0  79  20    0
# 1   0  90    0
# 2   0   2  108

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89        99
#            1       0.80      1.00      0.89        90
#            2       1.00      0.98      0.99       110
#
#     accuracy                           0.93       299
#    macro avg       0.93      0.93      0.92       299
# weighted avg       0.94      0.93      0.93       299
